# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# True

# %%
# Comprobamos las claves

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI existe y empieza por sk-proj-

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

openai = OpenAI()

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT 4.1 nano, el modelo increíblemente económico.

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 es 4.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Si cinco máquinas tardan cinco minutos en fabricar cinco piezas, ¿cuánto tiempo tardarán cien máquinas en fabricar cien piezas?

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Vamos a analizar el problema paso a paso:
#
# - **Datos iniciales:**
#   5 máquinas tardan 5 minutos en fabricar 5 piezas.
#
# Esto significa que:
#
# - Cada máquina fabrica 1 pieza en 5 minutos.
#
# Por lo tanto:
#
# - La tasa de producción de una máquina es: 1 pieza / 5 minutos.
#
# Ahora, queremos saber cuánto tiempo tardarán 100 máquinas en fabricar 100 piezas.
#
# - La tasa de producción de 100 máquinas es: 100 máquinas × (1 pieza / 5 minutos) = 100 / 5 = 20 piezas por minuto.
#
# Por tanto, el tiempo necesario para fabricar 100 piezas a esa tasa es:
#
# - Tiempo = (Cantidad de piezas) / (Tasa de producción) = 100 piezas / 20 piezas por minuto = 5 minutos.
#
# **Respuesta:**
#
# 100 máquinas tardarán **5 minutos** en fabricar 100 piezas.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Vamos a analizar el problema paso a paso:
#
# - **Datos iniciales:**
#   5 máquinas tardan 5 minutos en fabricar 5 piezas.
#
# Esto significa que:
#
# - Cada máquina fabrica 1 pieza en 5 minutos.
#
# Por lo tanto:
#
# - La tasa de producción de una máquina es: 1 pieza / 5 minutos.
#
# Ahora, queremos saber cuánto tiempo tardarán 100 máquinas en fabricar 100 piezas.
#
# - La tasa de producción de 100 máquinas es: 100 máquinas × (1 pieza / 5 minutos) = 100 / 5 = 20 piezas por minuto.
#
# Por tanto, el tiempo necesario para fabricar 100 piezas a esa tasa es:
#
# - Tiempo = (Cantidad de piezas) / (Tasa de producción) = 100 piezas / 20 piezas por minuto = 5 minutos.
#
# **Respuesta:**
#
# 100 máquinas tardarán **5 minutos** en fabricar 100 piezas.

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# Primero creamos el mensaje
messages = [{"role": "user", "content": "Elige un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic"}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    temperature=0.7,
)

print(f"Respuesta 1: {response.choices[0].message.content}")

# Luego leemos la idea de negocio:
business_idea = response.choices[0].message.content
problem = f"Presenta un problema en la industria {business_idea}, algo desafiante que pueda ser propicio para una solución con Agentic"
messages = [{"role": "assistant", "content": problem}]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    temperature=0.7,
)

print(f"Respuesta 2: {response.choices[0].message.content}")

problem_description = response.choices[0].message.content
solution = f"Propón una solución de IA con Agenticpara el siguiente problema: {problem_description}"
messages = [{"role": "assistant", "content": solution}]

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    temperature=0.7,
)

print(f"Respuesta 3: {response.choices[0].message.content}")
# Out:
# Respuesta 1: Una área de negocio que vale la pena explorar para una oportunidad de inteligencia artificial (IA) con Agentic es el **sector de la salud y bienestar**. Este campo presenta múltiples oportunidades para la implementación de soluciones basadas en IA que pueden mejorar la atención al paciente, optimizar operaciones y personalizar tratamientos.
#
# ### Oportunidades en el sector de la salud y bienestar:
#
# 1. **Telemedicina y Diagnóstico Asistido**:
#    - Desarrollar plataformas que utilicen IA para analizar síntomas y proporcionar diagnósticos preliminares, facilitando el acceso a atención médica remota.
#
# 2. **Monitoreo de Salud Predictivo**:
#    - Implementar sistemas que analicen datos de dispositivos wearables para prever problemas de salud antes de que ocurran, permitiendo intervenciones tempranas.
#
# 3. **Personalización de Tratamientos**:
#    - Utilizar algoritmos de IA para analizar el historial médico y genómico de los pacientes, creando tratamientos personalizados que aumenten la efectividad de los mismos.
#
# 4. **Optimización de Procesos Administrativos**:
#    - Implementar IA en la gestión de citas, registros médicos y facturación, reduciendo costos operativos y mejorando la eficiencia.
#
# 5. **Análisis de Imágenes Médicas**:
#    - Desarrollar soluciones de IA para el análisis de radiografías, resonancias magnéticas y otros estudios de imagen, ayudando a los médicos a identificar condiciones con mayor precisión.
#
# 6. **Asistentes Virtuales para Pacientes**:
#    - Crear chatbots o asistentes virtuales que puedan responder preguntas frecuentes de los pacientes, recordando citas y proporcionando información sobre medicamentos.
#
# 7. **Investigación y Desarrollo de Medicamentos**:
#    - Utilizar IA para acelerar el proceso de descubrimiento de fármacos, analizando grandes volúmenes de datos para identificar posibles compuestos efectivos.
#
# ### Conclusión
#
# El sector de la salud y bienestar es un área rica en desafíos que pueden ser abordados con soluciones de IA. Con un enfoque en la mejora de la calidad de vida y la optimización de recursos, Agentic podría encontrar un mercado receptivo y en constante crecimiento. Implementar tecnologías de IA en este sector no solo puede ser rentable, sino que también proporciona un impacto positivo en la sociedad.
# Respuesta 2: ### Problema en la Industria de la Salud y Bienestar: Desafíos en la Atención al Paciente
#
# **Contexto:**
# En el sector de la salud, la atención al paciente ha enfrentado múltiples desafíos, especialmente en un contexto post-pandemia. La creciente demanda de servicios médicos, combinada con la escasez de profesionales de la salud y la necesidad de ofrecer atención personalizada, ha puesto presión sobre los sistemas de salud en todo el mundo. Esto se traduce en tiempos de espera prolongados, diagnósticos tardíos y una experiencia general del paciente que puede verse afectada.
#
# ### Problemas Clave:
#
# 1. **Acceso Limitado a Atención Médica**:
#    - En muchas regiones, los pacientes enfrentan dificultades para acceder a atención médica oportuna, lo que puede resultar en el agravamiento de condiciones de salud.
#
# 2. **Sobrecarga de Información**:
#    - Los profesionales de la salud a menudo se ven abrumados por la gran cantidad de datos que deben gestionar, desde historiales médicos hasta resultados de pruebas, lo que dificulta la toma de decisiones rápidas y efectivas.
#
# 3. **Falta de Personalización en Tratamientos**:
#    - Los tratamientos a menudo son estándar y no se adaptan a las necesidades individuales de los pacientes, lo que puede reducir su efectividad.
#
# 4. **Ineficiencias Administrativas**:
#    - La gestión de citas, registros y facturación suele ser manual y propensa a errores, lo que consume tiempo y recursos que podrían destinarse a la atención al paciente.
#
# 5. **Dificultades en el Seguimiento Post-Tratamiento**:
#    - La falta de sistemas efectivos para el seguimiento de pacientes después de un tratamiento puede resultar en una atención insuficiente y en la falta de adherencia a los tratamientos prescritos.
#
# ### Oportunidades para la Implementación de IA:
#
# Agentic puede explorar diversas oportunidades en el sector de la salud y bienestar para abordar estos problemas:
#
# 1. **Plataformas de Telemedicina**:
#    - Desarrollar soluciones que integren IA para proporcionar diagnósticos preliminares y recomendaciones de tratamiento a través de consultas virtuales, mejorando el acceso a la atención médica.
#
# 2. **Sistemas de Monitoreo Predictivo**:
#    - Implementar IA para analizar datos de dispositivos wearables, anticipando problemas de salud antes de que se conviertan en emergencias. Esto puede incluir alertas automáticas para profesionales de la salud y pacientes.
#
# 3. **Optimización de Procesos con IA**:
#    - Utilizar IA para automatizar la gestión de citas y registros médicos, reduciendo errores y liberando tiempo para que el personal se enfoque en la atención al paciente.
#
# 4. **Análisis de Datos para Personalización**:
#    - Desarrollar algoritmos que analicen datos clínicos y genéticos para ofrecer tratamientos personalizados, aumentando la efectividad y satisfacción del paciente.
#
# 5. **Asistentes Virtuales**:
#    - Crear asistentes virtuales que puedan ayudar a los pacientes con recordatorios de medicamentos, responder preguntas frecuentes y facilitar la comunicación con los profesionales de salud.
#
# 6. **Análisis Avanzado de Imágenes**:
#    - Implementar soluciones de IA que mejoren la precisión en la interpretación de imágenes médicas, ayudando a los médicos a realizar diagnósticos más rápidos y precisos.
#
# ### Conclusión
#
# El sector de la salud y bienestar presenta una oportunidad significativa para la implementación de soluciones de inteligencia artificial. Al abordar problemas críticos como el acceso a la atención, la personalización de tratamientos y la optimización de procesos, Agentic puede contribuir a una mejora sustancial en la calidad de la atención médica y la experiencia del paciente. Este enfoque no solo es viable desde el punto de vista comercial, sino que también tiene el potencial de generar un impacto positivo en la vida de las personas.
# Respuesta 3: ### Solución de IA con Agentic para Mejorar la Atención al Paciente en la Industria de la Salud
#
# #### 1. **Plataforma de Telemedicina Inteligente**
#
# **Descripción**: Desarrollar una plataforma de telemedicina que integre inteligencia artificial para ofrecer diagnósticos preliminares y recomendaciones de tratamiento.
#
# - **Funcionalidades**:
#   - **Chatbots de triage**: Utilizar un sistema de IA que realice preguntas iniciales a los pacientes, analice sus síntomas y dirija a los pacientes a la atención adecuada (especialista, urgencias, etc.).
#   - **Historial médico accesible**: Permitir que los pacientes carguen y compartan su historial médico en la plataforma, facilitando el acceso a los profesionales de la salud.
#   - **Consultas virtuales**: Integrar video llamadas con herramientas de IA que asistan a los médicos en la evaluación de síntomas y en la elaboración de un plan de tratamiento.
#
# #### 2. **Sistema de Monitoreo Predictivo de Salud**
#
# **Descripción**: Implementar un sistema de monitoreo que utilice dispositivos wearables para recopilar datos en tiempo real y predecir problemas de salud.
#
# - **Funcionalidades**:
#   - **Análisis de datos biométricos**: Utilizar algoritmos de aprendizaje automático para analizar datos como la frecuencia cardíaca, niveles de glucosa y patrones de sueño para detectar anomalías.
#   - **Alertas automatizadas**: Crear un sistema que notifique a los profesionales de la salud y a los pacientes sobre posibles riesgos, permitiendo intervenciones oportunas.
#   - **Seguimiento continuo**: Ofrecer a los médicos acceso a un panel de control donde puedan monitorear la salud de sus pacientes de manera proactiva.
#
# #### 3. **Optimización Administrativa Mediante IA**
#
# **Descripción**: Implementar un sistema de gestión administrativa que utilice IA para automatizar procesos y reducir la carga de trabajo del personal.
#
# - **Funcionalidades**:
#   - **Gestión de citas automatizada**: Utilizar IA para programar citas, enviar recordatorios y reprogramar automáticamente en caso de cancelaciones.
#   - **Manejo de registros electrónicos**: Crear un sistema que facilite la entrada y recuperación de datos médicos, minimizando errores humanos y optimizando el flujo de trabajo.
#   - **Facturación automatizada**: Integrar herramientas de IA que manejen la facturación y verificación de seguros, reduciendo el tiempo de gestión y errores.
#
# #### 4. **Personalización de Tratamientos con Análisis de Datos**
#
# **Descripción**: Desarrollar algoritmos que analicen datos clínicos y genéticos para ofrecer tratamientos personalizados a los pacientes.
#
# - **Funcionalidades**:
#   - **Análisis de datos históricos**: Utilizar técnicas de minería de datos para identificar patrones en la eficacia de tratamientos en diferentes grupos de pacientes.
#   - **Recomendaciones personalizadas**: Proporcionar sugerencias de tratamientos basadas en el perfil único del paciente, incluyendo genética, historial médico y preferencias.
#   - **Seguimiento de resultados**: Implementar un sistema que mida la efectividad de los tratamientos personalizados y ajuste las recomendaciones en tiempo real.
#
# #### 5. **Asistentes Virtuales para Pacientes**
#
# **Descripción**: Crear asistentes virtuales que ayuden a los pacientes a gestionar su salud de manera más efectiva.
#
# - **Funcionalidades**:
#   - **Recordatorios de medicación**: Enviar notificaciones automáticas a los pacientes sobre cuándo tomar sus medicamentos y programar sus dosis.
#   - **Respuestas a consultas frecuentes**: Ofrecer un chatbot que responda preguntas comunes sobre condiciones de salud, tratamientos y procedimientos.
#   - **Conexión con profesionales**: Facilitar la comunicación entre pacientes y proveedores de atención, permitiendo que los pacientes planteen dudas o preocupaciones.
#
# #### 6. **Análisis de Imágenes Médicas con IA**
#
# **Descripción**: Implementar un sistema de IA para mejorar la interpretación de imágenes médicas, como radiografías y resonancias magnéticas.
#
# - **Funcionalidades**:
#   - **Detección de anomalías**: Utilizar modelos de IA para identificar automáticamente patrones y anomalías en imágenes, ayudando a los radiólogos en el diagnóstico.
#   - **Integración con historiales médicos**: Relacionar resultados de imágenes con datos clínicos para proporcionar un contexto más completo al médico.
#   - **Aprendizaje continuo**: Implementar un sistema que aprenda y mejore con cada revisión, aumentando la precisión de los diagnósticos con el tiempo.
#
# ### Conclusión
#
# La implementación de estas soluciones de inteligencia artificial en la industria de la salud y bienestar no solo tiene el potencial de abordar los problemas actuales en la atención al paciente, sino que también puede transformar la forma en que se brinda la atención médica. Al mejorar el acceso, optimizar procesos y personalizar tratamientos, Agentic puede contribuir significativamente a una experiencia de paciente más eficiente y satisfactoria, impactando positivamente en la salud de los individuos y en la eficiencia de los sistemas de salud.
